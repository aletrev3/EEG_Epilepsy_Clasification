# %% [markdown]
# <a href="https://colab.research.google.com/github/aletrev3/EEG_Epilepsy_Clasification/blob/main/EEG_Epilepsy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Guttag, J. (2010). CHB-MIT Scalp EEG Database (version 1.0.0). PhysioNet. RRID:SCR_007345. https://doi.org/10.13026/C2K01R
#
# Ali Shoeb. Application of Machine Learning to Epileptic Seizure Onset Detection and Treatment. PhD Thesis, Massachusetts Institute of Technology, September 2009.
#
#  Please include the standard citation for PhysioNet: (show more options)
# Goldberger, A., Amaral, L., Glass, L., Hausdorff, J., Ivanov, P. C., Mark, R., ... & Stanley, H. E. (2000). PhysioBank, PhysioToolkit, and PhysioNet: Components of a new research resource for complex physiologic signals. Circulation [Online]. 101 (23), pp. e215–e220. RRID:SCR_007345.

# %% [markdown]
# # **Data reading and observation**

# %%
#bring files from drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#read edf
import mne
#load file (chb01_01)
file = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_01.edf')
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/datos_eeg/chb01/chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /tmp/ipython-input-2318836757.py:4: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   file = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_01.edf')

# %%
#read chb01 (chb01_01.edf) as raw
data = file.get_data()
#23 signals per file
#256 samples per second
print("Number of channels:", str(len(data)))
print("Number of samples:", str(len(data[0])))
# Out:
# Number of channels: 23
# Number of samples: 921600

# %%
import matplotlib.pyplot as plt
#Comparison betwwen a non-seizure record and a seizure record (2 seconds each)
#Non-seizure file chb01_14
file_14 = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_14.edf')
data_14 = file_14.get_data()
#plotting file
chb01_14 = plt.plot(data_14[0, 445440:445952])
plt.title("A. Seconds 1740 to 1742 of chb01_14 as raw data (electrode 0)")
plt.show()

#Non-seizure file chb01_15
file_15 = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_15.edf')
data_15 = file_15.get_data()
#plotting file
chb01_15 = plt.plot(data_15[0, 445440:445952])
plt.title("A. Seconds 1740 to 1742 of chb01_15 as raw data (electrode 0)")
plt.show()
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/datos_eeg/chb01/chb01_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /tmp/ipython-input-3217751962.py:4: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   file_14 = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_14.edf')
# Extracting EDF parameters from /content/drive/MyDrive/datos_eeg/chb01/chb01_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /tmp/ipython-input-3217751962.py:12: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   file_15 = mne.io.read_raw_edf('/content/drive/MyDrive/datos_eeg/chb01/chb01_15.edf')

# %%
#Plotting all electrodes for chb01_15
chb01_15 = plt.plot(data_15[0:22, 445440:445952])
plt.title("A. Seconds 1740 to 1742 of chb01_15 as raw data (all electrodes)\nSeizure")
plt.show()

#Plotting all electrodes for chb01_14
chb01_14 = plt.plot(data_14[0:22, 445440:445952])
plt.title("A. Seconds 1740 to 1742 of chb01_14 as raw data (all electrodes)\nNon-seizure")
plt.axis([0, 20, -0.0002, 0.0002])
plt.show()
